# %%
#Import libraries below

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Import the data and look at it - csv file for shark attacks

# %%
data = pd.read_csv("../desktop/attacks.csv",encoding = "ISO-8859-1")

# %%
data.shape
print("the dataframe has 25,723 rows and 24 columns")
# Out:
# the dataframe has 25,723 rows and 24 columns

# %%
data.head(10)
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7    2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# ...

# %%
data.tail(10)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25713         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25714         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25715         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25716         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25717         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 25713  ...      NaN                    NaN  NaN          NaN  NaN
# ...

# %%
print(data.columns)
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
print(data.keys)
# Out:
# <bound method NDFrame.keys of       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# ...

# %%
#Chek repetitions

# %%
print("Some rows may be repeated, in order to make sure this does not happen I will use the 'drop.duplicates' function.")
# Out:
# Some columns may be repeated, in order to make sure this does not happen I will use the 'drop.duplicates' function.

# %%
actual_data = data.drop_duplicates()
actual_data.shape
# Out:
# (6312, 24)

# %%
count_row = data.shape[0]
print(count_row)
count_row2 =actual_data.shape[0]
print(count_row2)
# Out:
# 25723
# 6312

# %%
rows_repeated = count_row - count_row2
print(rows_repeated)
# Out:
# 19411

# %%
print("It was a good idea to check for repeated rows because now we only have,",count_row2,"rows,",rows_repeated,"less than before.")
# Out:
# It was a good idea to check for repeated rows because now we only have, 6312 rows, 19411 less than before.

# %%
print(actual_data.isnull())
print("Using the isnull() method I can see that there are some empty values n/a, and now I want to see in which places those values are misssing")
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 6307         False   True   True   True     True   True      True      True
# 6308         False   True   True   True     True   True      True      True
# 6309         False   True   True   True     True   True      True      True
# 8702          True   True   True   True     True   True      True      True
# 25722        False   True   True   True     True   True      True      True
#
# ...

# %%
print(actual_data.isnull().sum())
# Out:
# Case Number                  2
# Date                        10
# Year                        12
# Type                        14
# Country                     60
# Area                       465
# Location                   550
# Activity                   554
# Name                       220
# Sex                        575
# Age                       2841
# Injury                      38
# Fatal (Y/N)                549
# Time                      3364
# Species                   2848
# Investigator or Source      27
# pdf                         10
# href formula                11
# href                        10
# Case Number.1               10
# Case Number.2               10
# original order               3
# Unnamed: 22               6311
# Unnamed: 23               6310
# dtype: int64

# %%
print("Now we can see how many values are missing for each column, and it appears that, Unnamed:23 and Unnamed:24 suffer most from this problem, followed by Time, Species, and Age.")
# Out:
# Now we can see how many values are missing for each column, and it appears that, Unnamed:23 and Unnamed:24 suffer most from this problem, followed by Time, Species, and Age.

# %% [markdown]
# There are too many columns describind the date of the attack. So im going to drop 'Case Number.1', 'Case Number.2', and keep the 'Case number' and the 'Date' columns

# %%
actual_data2 = actual_data.drop(columns=['Case Number.1', 'Case Number.2'])

# %%
actual_data2
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          nan     NaN         NaN        NaN
# 6308            0          nan     NaN         NaN        NaN
# 6309            0          nan     NaN         NaN        NaN
# 8702          NaN          nan     NaN         NaN        NaN
# 25722          xx          nan     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %% [markdown]
# Now we have 22 columns

# %% [markdown]
# I believe that all the rows under column unnamed:22 and unnamed:23 have missing values and therefore are not usefull. If i find that to be true I will also drop those columns.

# %%
actual_data2['Unnamed: 22'].isnull().sum()
# Out:
# 6311

# %%
actual_data2['Unnamed: 23'].isnull().sum()
# Out:
# 6310

# %%
actual_data2.shape
# Out:
# (6312, 22)

# %%
actual_data3 = actual_data2.drop(columns=['Unnamed: 22', 'Unnamed: 23'])

# %%
actual_data3.shape
# Out:
# (6312, 20)

# %% [markdown]
# I have dropped both colums because they did not have any significant data. Now we have 20 columns in our dataframe.

# %% [markdown]
# I will also drop the columns that I believe will have no use in my plotting and examination of the data.

# %%
final_data = actual_data3.drop(columns=['Case Number', 'Species ', 'Location', 'Area', 'pdf', 'Time', 'Investigator or Source', 'href formula', 'href', 'original order'])

# %%
final_data.shape
# Out:
# (6312, 10)

# %%
final_data.head()
# Out:
#           Date    Year        Type    Country     Activity             Name  \
# 0  25-Jun-2018  2018.0     Boating        USA     Paddling      Julie Wolfe
# 1  18-Jun-2018  2018.0  Unprovoked        USA     Standing  Adyson McNeely
# 2  09-Jun-2018  2018.0     Invalid        USA      Surfing      John Denges
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA      Surfing             male
# 4  04-Jun-2018  2018.0    Provoked     MEXICO  Free diving   Gustavo Ramos
#
#   Sex   Age                                             Injury Fatal (Y/N)
# 0    F   57  No injury to occupant, outrigger canoe and pad...           N
# 1    F   11                         Minor injury to left thigh           N
# 2    M   48       Injury to left lower leg from surfboard skeg           N
# 3    M  NaN                          Minor injury to lower leg           N
# 4    M  NaN  Lacerations to leg & hand shark PROVOKED INCIDENT           N

# %%
final_data.tail()
# Out:
#       Date  Year Type Country Activity Name Sex   Age Injury Fatal (Y/N)
# 6307   nan   NaN  NaN     NaN      NaN  NaN  NaN  NaN    NaN         NaN
# 6308   nan   NaN  NaN     NaN      NaN  NaN  NaN  NaN    NaN         NaN
# 6309   nan   NaN  NaN     NaN      NaN  NaN  NaN  NaN    NaN         NaN
# 8702   nan   NaN  NaN     NaN      NaN  NaN  NaN  NaN    NaN         NaN
# 25722  nan   NaN  NaN     NaN      NaN  NaN  NaN  NaN    NaN         NaN

# %% [markdown]
# There are still rows with missing values so i will go ahed and delete those.

# %%
final_data.isnull().sum().sort_values(ascending=False)
# Out:
# Age            2841
# Sex             575
# Activity        554
# Fatal (Y/N)     549
# Name            220
# Country          60
# Injury           38
# Type             14
# Year             12
# Date              0
# dtype: int64

# %%
final_data.dropna()
# Out:
#              Date    Year        Type             Country  \
# 0     25-Jun-2018  2018.0     Boating                 USA
# 1     18-Jun-2018  2018.0  Unprovoked                 USA
# 2     09-Jun-2018  2018.0     Invalid                 USA
# 6     03-Jun-2018  2018.0  Unprovoked              BRAZIL
# 7     27-May-2018  2018.0  Unprovoked                 USA
# ...           ...     ...         ...                 ...
# 6243        1960s     0.0  Unprovoked                IRAQ
# 6254  Before 1957     0.0    Provoked                CUBA
# 6265    1941-1942     0.0  Unprovoked                IRAQ
# 6276  Early 1930s     0.0  Unprovoked              BELIZE
# 6301    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                                                Activity  \
# 0                                              Paddling
# 1                                              Standing
# 2                                               Surfing
# ...

# %% [markdown]
# Now i have my final data. With 3091 rows and 10 columns which will be useful in order to find evidence and correlations in the data.

# %%
final_data.to_csv(r'desktop\clean_data.csv')
